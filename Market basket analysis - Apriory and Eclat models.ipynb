# %% [markdown]
# ##  Market basket analysis -  Apriory and Eclat models.
#
# Groceries dataset is going to be analysed through Apriory and Eclat model to see which combination of products are recommended.

# %%
#Installing apyori
# !pip install apyori
# Out:
# Requirement already satisfied: apyori in c:\users\maria\anaconda3\lib\site-packages (1.1.2)

# %%
#Importing libraries

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings('ignore') # We can suppress the warnings

# %% [markdown]
# ### 1. EDA Analysis

# %%
#Loading the dataset
dataset = pd.read_csv('Groceries_dataset.csv')
dataset.head()
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21/07/2015    tropical fruit
# 1           2552  05/01/2015        whole milk
# 2           2300  19/09/2015         pip fruit
# 3           1187  12/12/2015  other vegetables
# 4           3037  01/02/2015        whole milk

# %%
#checking the shape of the dataset
dataset.shape
# Out:
# (38765, 3)

# %%
##Checking data types on dataset to check variables
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38765 entries, 0 to 38764
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Member_number    38765 non-null  int64
#  1   Date             38765 non-null  object
#  2   itemDescription  38765 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 908.7+ KB

# %%
## Before proceding, Data needs to be converted to from object to datetime type
dataset['Date'] = pd.to_datetime(dataset['Date'])
dataset.head()
# Out:
#    Member_number       Date   itemDescription
# 0           1808 2015-07-21    tropical fruit
# 1           2552 2015-05-01        whole milk
# 2           2300 2015-09-19         pip fruit
# 3           1187 2015-12-12  other vegetables
# 4           3037 2015-01-02        whole milk

# %%
#Verify if there is any null value
#there are no any null value
dataset.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
#checking summary statistics
dataset.describe()
# Out:
#        Member_number
# count   38765.000000
# mean     3003.641868
# std      1153.611031
# min      1000.000000
# 25%      2002.000000
# 50%      3005.000000
# 75%      4007.000000
# max      5000.000000

# %%
#checking the duplicates in the dataset
duplicate_rows=dataset[dataset.duplicated()] 
print('number of duplicate rows: ', duplicate_rows.shape)
# Out:
# number of duplicate rows:  (759, 3)

# %%
# Used to count the number of rows before removing the data 
dataset.count()
# Out:
# Member_number      38765
# Date               38765
# itemDescription    38765
# dtype: int64

# %%
# Dropping the duplicates 
dataset = dataset.drop_duplicates() 
dataset.head(5)
# Out:
#    Member_number       Date   itemDescription
# 0           1808 2015-07-21    tropical fruit
# 1           2552 2015-05-01        whole milk
# 2           2300 2015-09-19         pip fruit
# 3           1187 2015-12-12  other vegetables
# 4           3037 2015-01-02        whole milk

# %%
#checking shape of data after dropping duplicates
dataset.shape
# Out:
# (38006, 3)

# %%
## Use lamdba funtion to group the data based on Member_number and Date
dataset1= dataset.groupby(['Member_number', 'Date']).agg({'itemDescription': lambda x: ', '.join(x)}).reset_index()
dataset1.head()
# Out:
#    Member_number       Date                                   itemDescription
# 0           1000 2014-06-24                   whole milk, pastry, salty snack
# 1           1000 2015-03-15  sausage, whole milk, semi-finished bread, yogurt
# 2           1000 2015-05-27                          soda, pickled vegetables
# 3           1000 2015-07-24                      canned beer, misc. beverages
# 4           1000 2015-11-25                         sausage, hygiene articles

# %%
#how many items do you have as a maximum in your data
transactions = []
for row in range(0,len(dataset1)):
    transactions.append(dataset1['itemDescription'][row].split(','))
transactions[:2]
# Out:
# [['whole milk', ' pastry', ' salty snack'],
#  ['sausage', ' whole milk', ' semi-finished bread', ' yogurt']]

# %%
#Training the model with the dataset

from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.001, min_confidence = 0.1, min_lift = 1, 
                min_length = 2, max_length = 2)


#minimum support: (number of transactions with the products/ total transactions)
#minimum confidence: there is not a specific rule/value. We will have a level of confidence of 0.1
#minimum lift: it has to be at least 3 to be relevant. We will set 1 as minimum lift
#min/max length: minimum/maximum number of elements we want to have in the rule (left and right)

# %%
#Displaying the first results coming directly from the output of the apriori function

results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({' beef', ' whole milk'}), support=0.0012697988371315912, ordered_statistics=[OrderedStatistic(items_base=frozenset({' beef'}), items_add=frozenset({' whole milk'}), confidence=0.1347517730496454, lift=1.5752271719858155)]),
#  RelationRecord(items=frozenset({' beef', 'whole milk'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' beef'}), items_add=frozenset({'whole milk'}), confidence=0.10638297872340427, lift=1.469813952574606)]),
#  RelationRecord(items=frozenset({' beverages', 'sausage'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' beverages'}), items_add=frozenset({'sausage'}), confidence=0.11111111111111112, lift=2.2137890220446814)]),
#  RelationRecord(items=frozenset({' cat food', 'whole milk'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' cat food'}), items_add=frozenset({'whole milk'}), confidence=0.11278195488721804, lift=1.5582238143836045)]),
#  RelationRecord(items=frozenset({' chewing gum', ' whole milk'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' chewing gum'}), items_add=frozenset({' whole milk'}), confidence=0.11111111111111112, lift=1.2988715277777778)]),
#  RelationRecord(items=frozenset({' chicken', ' whole milk'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' chicken'}), items_add=frozenset({' whole milk'}), confidence=0.15625, lift=1.8265380859375)]),
#  RelationRecord(items=frozenset({' citrus fruit', ' whole milk'}), support=0.001871282496825503, ordered_statistics=[OrderedStatistic(items_base=frozenset({' citrus fruit'}), items_add=frozenset({' whole milk'}), confidence=0.12334801762114538, lift=1.441919052863436)]),
#  RelationRecord(items=frozenset({' frankfurter', ' other vegetables'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' frankfurter'}), items_add=frozenset({' other vegetables'}), confidence=0.1875, lift=2.8425151975683893)]),
#  RelationRecord(items=frozenset({' frankfurter', ' whole milk'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' frankfurter'}), items_add=frozenset({' whole milk'}), confidence=0.1875, lift=2.191845703125)]),
#  RelationRecord(items=frozenset({' newspapers', 'whole milk'}), support=0.003207912851700862, ordered_statistics=[OrderedStatistic(items_base=frozenset({' newspapers'}), items_add=frozenset({'whole milk'}), confidence=0.10690423162583518, lift=1.4770157135894477)]),
#  RelationRecord(items=frozenset({' whole milk', ' oil'}), support=0.0012697988371315912, ordered_statistics=[OrderedStatistic(items_base=frozenset({' oil'}), items_add=frozenset({' whole milk'}), confidence=0.11875, lift=1.3881689453125)]),
#  RelationRecord(items=frozenset({' onions', ' whole milk'}), support=0.001403461872619127, ordered_statistics=[OrderedStatistic(items_base=frozenset({' onions'}), items_add=frozenset({' whole milk'}), confidence=0.12352941176470586, lift=1.4440395220588231)]),
#  RelationRecord(items=frozenset({' sausage', ' other vegetables'}), support=0.001603956425850431, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' other vegetables'}), confidence=0.15789473684210525, lift=2.3936970084786435)]),
#  RelationRecord(items=frozenset({'berries', ' other vegetables'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries'}), items_add=frozenset({' other vegetables'}), confidence=0.13580246913580246, lift=2.058776439391097)]),
#  RelationRecord(items=frozenset({'frankfurter', ' other vegetables'}), support=0.00360890195816347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frankfurter'}), items_add=frozenset({' other vegetables'}), confidence=0.111340206185567, lift=1.6879265503086516)]),
#  RelationRecord(items=frozenset({'meat', ' other vegetables'}), support=0.001403461872619127, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat'}), items_add=frozenset({' other vegetables'}), confidence=0.10552763819095476, lift=1.5998075483801988)]),
#  RelationRecord(items=frozenset({' pip fruit', 'whole milk'}), support=0.0024059346387756467, ordered_statistics=[OrderedStatistic(items_base=frozenset({' pip fruit'}), items_add=frozenset({'whole milk'}), confidence=0.11464968152866242, lift=1.584028794749193)]),
#  RelationRecord(items=frozenset({' pork', ' soda'}), support=0.0010693042839002875, ordered_statistics=[OrderedStatistic(items_base=frozenset({' pork'}), items_add=frozenset({' soda'}), confidence=0.11267605633802817, lift=1.824644838729346)]),
#  RelationRecord(items=frozenset({' pork', ' whole milk'}), support=0.0012697988371315912, ordered_statistics=[OrderedStatistic(items_base=frozenset({' pork'}), items_add=frozenset({' whole milk'}), confidence=0.13380281690140844, lift=1.5641340228873237)]),
#  RelationRecord(items=frozenset({' pork', 'sausage'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' pork'}), items_add=frozenset({'sausage'}), confidence=0.1056338028169014, lift=2.1046585772959996)]),
#  RelationRecord(items=frozenset({' sausage', ' rolls/buns'}), support=0.0015371249081066632, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' rolls/buns'}), confidence=0.15131578947368424, lift=2.1896887407105776)]),
#  RelationRecord(items=frozenset({' sausage', ' soda'}), support=0.0013366303548753592, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' soda'}), confidence=0.13157894736842107, lift=2.130753018910914)]),
#  RelationRecord(items=frozenset({' sausage', ' whole milk'}), support=0.002004945532313039, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' whole milk'}), confidence=0.19736842105263158, lift=2.307206003289474)]),
#  RelationRecord(items=frozenset({' sausage', ' yogurt'}), support=0.001871282496825503, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' yogurt'}), confidence=0.1842105263157895, lift=3.142921442717398)]),
#  RelationRecord(items=frozenset({' whole milk', ' tropical fruit'}), support=0.0024059346387756467, ordered_statistics=[OrderedStatistic(items_base=frozenset({' tropical fruit'}), items_add=frozenset({' whole milk'}), confidence=0.10285714285714287, lift=1.2023839285714286)]),
#  RelationRecord(items=frozenset({' whole milk', 'bottled beer'}), support=0.0025395976742631824, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bottled beer'}), items_add=frozenset({' whole milk'}), confidence=0.15833333333333333, lift=1.8508919270833333)]),
#  RelationRecord(items=frozenset({'citrus fruit', ' whole milk'}), support=0.004344048653344918, ordered_statistics=[OrderedStatistic(items_base=frozenset({'citrus fruit'}), items_add=frozenset({' whole milk'}), confidence=0.11443661971830986, lift=1.3377462037852113)]),
#  RelationRecord(items=frozenset({'curd', ' whole milk'}), support=0.0011361358016440553, ordered_statistics=[OrderedStatistic(items_base=frozenset({'curd'}), items_add=frozenset({' whole milk'}), confidence=0.1103896103896104, lift=1.290437297077922)]),
#  RelationRecord(items=frozenset({' whole milk', 'frankfurter'}), support=0.00394305954688231, ordered_statistics=[OrderedStatistic(items_base=frozenset({'frankfurter'}), items_add=frozenset({' whole milk'}), confidence=0.12164948453608249, lift=1.4220634664948455)]),
#  RelationRecord(items=frozenset({'ham', ' whole milk'}), support=0.001804450979081735, ordered_statistics=[OrderedStatistic(items_base=frozenset({'ham'}), items_add=frozenset({' whole milk'}), confidence=0.13106796116504854, lift=1.5321639866504855)]),
#  RelationRecord(items=frozenset({'hamburger meat', ' whole milk'}), support=0.001603956425850431, ordered_statistics=[OrderedStatistic(items_base=frozenset({'hamburger meat'}), items_add=frozenset({' whole milk'}), confidence=0.10572687224669602, lift=1.2359306167400879)]),
#  RelationRecord(items=frozenset({' whole milk', 'meat'}), support=0.0015371249081066632, ordered_statistics=[OrderedStatistic(items_base=frozenset({'meat'}), items_add=frozenset({' whole milk'}), confidence=0.11557788944723618, lift=1.3510874685929648)]),
#  RelationRecord(items=frozenset({'other vegetables', ' whole milk'}), support=0.006415825703401724, ordered_statistics=[OrderedStatistic(items_base=frozenset({'other vegetables'}), items_add=frozenset({' whole milk'}), confidence=0.11428571428571428, lift=1.3359821428571428)]),
#  RelationRecord(items=frozenset({'pork', ' whole milk'}), support=0.0029405867807257902, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pork'}), items_add=frozenset({' whole milk'}), confidence=0.10653753026634383, lift=1.2454070823244552)]),
#  RelationRecord(items=frozenset({'sausage', ' whole milk'}), support=0.006081668114682885, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sausage'}), items_add=frozenset({' whole milk'}), confidence=0.1211717709720373, lift=1.4164790695739016)])]

# %% [markdown]
# **Discussion** Under this model, the results shown that the strongest combination will be between other vegetables and whole milk

# %% [markdown]
# ### 1.2. Apriory model

# %% [markdown]
# Data is going to be processed first using the Apriory model to check the results.

# %%
#Putting the results well organised into a Pandas Data Frame

def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 
                                                               'Support', 'Confidence', 'Lift'])

# %%
#Displaying non sorted results

resultsinDataFrame
# Out:
#       Left Hand Side    Right Hand Side   Support  Confidence      Lift
# 0               beef         whole milk  0.001270    0.134752  1.575227
# 1               beef         whole milk  0.001002    0.106383  1.469814
# 2          beverages            sausage  0.001002    0.111111  2.213789
# 3           cat food         whole milk  0.001002    0.112782  1.558224
# 4        chewing gum         whole milk  0.001002    0.111111  1.298872
# 5            chicken         whole milk  0.001002    0.156250  1.826538
# 6       citrus fruit         whole milk  0.001871    0.123348  1.441919
# 7        frankfurter   other vegetables  0.001002    0.187500  2.842515
# 8        frankfurter         whole milk  0.001002    0.187500  2.191846
# 9         newspapers         whole milk  0.003208    0.106904  1.477016
# 10               oil         whole milk  0.001270    0.118750  1.388169
# 11            onions         whole milk  0.001403    0.123529  1.444040
# 12           sausage   other vegetables  0.001604    0.157895  2.393697
# 13           berries   other vegetables  0.001470    0.135802  2.058776
# 14       frankfurter   other vegetables  0.003609    0.111340  1.687927
# 15              meat   other vegetables  0.001403    0.105528  1.599808
# 16         pip fruit         whole milk  0.002406    0.114650  1.584029
# 17              pork               soda  0.001069    0.112676  1.824645
# 18              pork         whole milk  0.001270    0.133803  1.564134
# 19              pork            sausage  0.001002    0.105634  2.104659
# 20           sausage         rolls/buns  0.001537    0.151316  2.189689
# 21           sausage               soda  0.001337    0.131579  2.130753
# 22           sausage         whole milk  0.002005    0.197368  2.307206
# 23           sausage             yogurt  0.001871    0.184211  3.142921
# 24    tropical fruit         whole milk  0.002406    0.102857  1.202384
# 25      bottled beer         whole milk  0.002540    0.158333  1.850892
# 26      citrus fruit         whole milk  0.004344    0.114437  1.337746
# 27              curd         whole milk  0.001136    0.110390  1.290437
# 28       frankfurter         whole milk  0.003943    0.121649  1.422063
# 29               ham         whole milk  0.001804    0.131068  1.532164
# 30    hamburger meat         whole milk  0.001604    0.105727  1.235931
# 31              meat         whole milk  0.001537    0.115578  1.351087
# 32  other vegetables         whole milk  0.006416    0.114286  1.335982
# 33              pork         whole milk  0.002941    0.106538  1.245407
# 34           sausage         whole milk  0.006082    0.121172  1.416479

# %%
#Displaying the results sorted by descending lifts
# lifts higher will be the highest combination
resultsinDataFrame.nlargest(n = 10, columns = 'Lift')
# Out:
#    Left Hand Side    Right Hand Side   Support  Confidence      Lift
# 23        sausage             yogurt  0.001871    0.184211  3.142921
# 7     frankfurter   other vegetables  0.001002    0.187500  2.842515
# 12        sausage   other vegetables  0.001604    0.157895  2.393697
# 22        sausage         whole milk  0.002005    0.197368  2.307206
# 2       beverages            sausage  0.001002    0.111111  2.213789
# 8     frankfurter         whole milk  0.001002    0.187500  2.191846
# 20        sausage         rolls/buns  0.001537    0.151316  2.189689
# 21        sausage               soda  0.001337    0.131579  2.130753
# 19           pork            sausage  0.001002    0.105634  2.104659
# 13        berries   other vegetables  0.001470    0.135802  2.058776

# %% [markdown]
# **Discussion**: After anaylising the results, it can be noted that strongest combination will be sausages and yogurt following by frankfurter sausages which go with other vegetables. It would be recommended to place the sausages fridges where vegetables section.

# %% [markdown]
# ### 1.3. Eclat model evaluation.

# %% [markdown]
# The same data is going to be processed using the Eclat model to check the results.

# %%
#Training the model with the dataset

from apyori import apriori
rules = apriori(transactions = transactions, min_support = 0.001, min_confidence = 0.1, min_lift = 2, 
                min_length = 2, max_length = 2)



#minimum support: (number of transactions with the products/ total transactions)
#minimum confidence: there is not a specific rule/value. We start with 0.80 and see where we get a good result
#minimum lift: it has to be at least 3 to be relevant
#min/max length: minimum/maximum number of elements we want to have in the rule (left and right)

# %%
#Displaying the first results coming directly from the output of the apriori function

results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({' beverages', 'sausage'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' beverages'}), items_add=frozenset({'sausage'}), confidence=0.11111111111111112, lift=2.2137890220446814)]),
#  RelationRecord(items=frozenset({' frankfurter', ' other vegetables'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' frankfurter'}), items_add=frozenset({' other vegetables'}), confidence=0.1875, lift=2.8425151975683893)]),
#  RelationRecord(items=frozenset({' frankfurter', ' whole milk'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' frankfurter'}), items_add=frozenset({' whole milk'}), confidence=0.1875, lift=2.191845703125)]),
#  RelationRecord(items=frozenset({' sausage', ' other vegetables'}), support=0.001603956425850431, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' other vegetables'}), confidence=0.15789473684210525, lift=2.3936970084786435)]),
#  RelationRecord(items=frozenset({'berries', ' other vegetables'}), support=0.0014702933903628951, ordered_statistics=[OrderedStatistic(items_base=frozenset({'berries'}), items_add=frozenset({' other vegetables'}), confidence=0.13580246913580246, lift=2.058776439391097)]),
#  RelationRecord(items=frozenset({' pork', 'sausage'}), support=0.0010024727661565194, ordered_statistics=[OrderedStatistic(items_base=frozenset({' pork'}), items_add=frozenset({'sausage'}), confidence=0.1056338028169014, lift=2.1046585772959996)]),
#  RelationRecord(items=frozenset({' sausage', ' rolls/buns'}), support=0.0015371249081066632, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' rolls/buns'}), confidence=0.15131578947368424, lift=2.1896887407105776)]),
#  RelationRecord(items=frozenset({' sausage', ' soda'}), support=0.0013366303548753592, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' soda'}), confidence=0.13157894736842107, lift=2.130753018910914)]),
#  RelationRecord(items=frozenset({' sausage', ' whole milk'}), support=0.002004945532313039, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' whole milk'}), confidence=0.19736842105263158, lift=2.307206003289474)]),
#  RelationRecord(items=frozenset({' sausage', ' yogurt'}), support=0.001871282496825503, ordered_statistics=[OrderedStatistic(items_base=frozenset({' sausage'}), items_add=frozenset({' yogurt'}), confidence=0.1842105263157895, lift=3.142921442717398)])]

# %%
#Putting the results well organised into a Pandas DF

def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    return list(zip(lhs, rhs, supports))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Product 1', 'Product 2', 'Support'])

# %%
#Displaying the results sorted by descending supports
#this is easy to read. It produces vertical results

resultsinDataFrame.nlargest(n = 10, columns = 'Support')
# Out:
#       Product 1          Product 2   Support
# 8       sausage         whole milk  0.002005
# 9       sausage             yogurt  0.001871
# 3       sausage   other vegetables  0.001604
# 6       sausage         rolls/buns  0.001537
# 4       berries   other vegetables  0.001470
# 7       sausage               soda  0.001337
# 0     beverages            sausage  0.001002
# 1   frankfurter   other vegetables  0.001002
# 2   frankfurter         whole milk  0.001002
# 5          pork            sausage  0.001002

# %% [markdown]
# **Discussion:** Under this model, the results shown that the strongest combination will be quite similar to the previous Apriory analysis, where sausages have a stronger support with whole milk followed by sausages and yogurt. The third combination will be sausage with other vegetables.
